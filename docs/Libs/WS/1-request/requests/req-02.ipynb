# %% [markdown]
# # Request Quickstart
#
# *参见：<https://requests.readthedocs.io/en/latest/user/quickstart/>*
#
# 1. Make a Request
# 2. Passing Parameters In URLs
# 3. Response Content
# 4. Binary Response Content
# 5. JSON Response Content
# 6. Raw Response Content
# 7. Custom Headers
# 8. More complicated POST requests
# 9. POST a Multipart-Encoded File
# 10. Response Status Codes
# 11. Response Headers
# 12. Cookies
# 13. Redirection and History
# 14. Timeouts
# 15. Errors and Exceptions

# %% [markdown]
# ## 1. Make a Request

# %%
import requests # Begin by importing the Requests module
r_by_get = requests.get('https://api.github.com/events') # Get GitHub’s public timeline
r_by_post = requests.post('https://httpbin.org/post', data={'key': 'value'}) # make an HTTP POST request
r_by_put = requests.put('https://httpbin.org/put', data={'key': 'value'})
r_by_delete = requests.delete('https://httpbin.org/delete')
r_by_head = requests.head('https://httpbin.org/get')
r_by_options = requests.options('https://httpbin.org/get')
r_by_get
# Out:
# <Response [200]>

# %% [markdown]
# ## 2. Passing Parameters In URLs

# %%
import requests
payload = {'key1': 'value1', 'key2': 'value2'} # to provide these arguments as a dictionary of strings
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
payload = {'key1': 'value1', 'key2': ['value2', 'value3']} # pass a list of items as a value
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %% [markdown]
# ## 3. Response Content

# %%
import requests
r = requests.get('https://api.github.com/events')
r.text
r.encoding
r.encoding = 'ISO-8859-1'
r.text
# Out:
# '[{"id":"7171020222","type":"PushEvent","actor":{"id":176320694,"login":"AREXTOVID","display_login":"AREXTOVID","gravatar_id":"","url":"https://api.github.com/users/AREXTOVID","avatar_url":"https://avatars.githubusercontent.com/u/176320694?"},"repo":{"id":976732139,"name":"AREXTOVID/laravel-repository-service-pattern","url":"https://api.github.com/repos/AREXTOVID/laravel-repository-service-pattern"},"payload":{"repository_id":976732139,"push_id":29465851873,"ref":"refs/heads/main","head":"da255476a41120657f7a6c7d7a4ba84ce9a44236","before":"0763994d92985e9aa15fd7504fd5c62c7ee94a63"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020218","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":1116307698,"name":"dallabroda/python-action-template","url":"https://api.github.com/repos/dallabroda/python-action-template"},"payload":{"repository_id":1116307698,"push_id":29465851874,"ref":"refs/heads/main","head":"d368d2fc1b69812b42c1d8a049e89d147fa8c606","before":"5b874641ec035b98f1ee003dfc8dc55b79991796"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020195","type":"PushEvent","actor":{"id":68215251,"login":"vrcorp","display_login":"vrcorp","gravatar_id":"","url":"https://api.github.com/users/vrcorp","avatar_url":"https://avatars.githubusercontent.com/u/68215251?"},"repo":{"id":1117703620,"name":"vrcorp/captcha-list-vr","url":"https://api.github.com/repos/vrcorp/captcha-list-vr"},"payload":{"repository_id":1117703620,"push_id":29465851800,"ref":"refs/heads/main","head":"d84df4f74d1f53d1ad725c65c8928af08e5e78ba","before":"8cd63080122049ca60c8d15aab90ed611896d5b0"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020188","type":"PushEvent","actor":{"id":187185894,"login":"tylers2222","display_login":"tylers2222","gravatar_id":"","url":"https://api.github.com/users/tylers2222","avatar_url":"https://avatars.githubusercontent.com/u/187185894?"},"repo":{"id":1114132487,"name":"tylers2222/Product-Creation-Agent","url":"https://api.github.com/repos/tylers2222/Product-Creation-Agent"},"payload":{"repository_id":1114132487,"push_id":29465851862,"ref":"refs/heads/main","head":"050da90961e93bee5659066d5886d59cec4cf89e","before":"ce72db60aaf72445df7b31d10502f3ae84b118e8"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020183","type":"PushEvent","actor":{"id":201428757,"login":"JShaurel","display_login":"JShaurel","gravatar_id":"","url":"https://api.github.com/users/JShaurel","avatar_url":"https://avatars.githubusercontent.com/u/201428757?"},"repo":{"id":976674514,"name":"JShaurel/the-dragon-news","url":"https://api.github.com/repos/JShaurel/the-dragon-news"},"payload":{"repository_id":976674514,"push_id":29465851853,"ref":"refs/heads/main","head":"7495425a4cec3307464bf1ec58499a00913d77aa","before":"36c28f6f25902695d7d8e88286ed071760d05a1d"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020182","type":"PushEvent","actor":{"id":244841556,"login":"escapingwork","display_login":"escapingwork","gravatar_id":"","url":"https://api.github.com/users/escapingwork","avatar_url":"https://avatars.githubusercontent.com/u/244841556?"},"repo":{"id":1099385184,"name":"escapingwork/teenagerspopulation","url":"https://api.github.com/repos/escapingwork/teenagerspopulation"},"payload":{"repository_id":1099385184,"push_id":29465851857,"ref":"refs/heads/main","head":"1945c365b27b613e263f2c2f28356b6304198758","before":"dce2348bf59d09e2856e46aa01e5e9cde984947c"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020181","type":"PushEvent","actor":{"id":241543984,"login":"fahadeleidy-design","display_login":"fahadeleidy-design","gravatar_id":"","url":"https://api.github.com/users/fahadeleidy-design","avatar_url":"https://avatars.githubusercontent.com/u/241543984?"},"repo":{"id":1097444731," ...

# %% [markdown]
# ## 4. Binary Response Content

# %%
r.content
# Out:
# b'[{"id":"7171020222","type":"PushEvent","actor":{"id":176320694,"login":"AREXTOVID","display_login":"AREXTOVID","gravatar_id":"","url":"https://api.github.com/users/AREXTOVID","avatar_url":"https://avatars.githubusercontent.com/u/176320694?"},"repo":{"id":976732139,"name":"AREXTOVID/laravel-repository-service-pattern","url":"https://api.github.com/repos/AREXTOVID/laravel-repository-service-pattern"},"payload":{"repository_id":976732139,"push_id":29465851873,"ref":"refs/heads/main","head":"da255476a41120657f7a6c7d7a4ba84ce9a44236","before":"0763994d92985e9aa15fd7504fd5c62c7ee94a63"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020218","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":1116307698,"name":"dallabroda/python-action-template","url":"https://api.github.com/repos/dallabroda/python-action-template"},"payload":{"repository_id":1116307698,"push_id":29465851874,"ref":"refs/heads/main","head":"d368d2fc1b69812b42c1d8a049e89d147fa8c606","before":"5b874641ec035b98f1ee003dfc8dc55b79991796"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020195","type":"PushEvent","actor":{"id":68215251,"login":"vrcorp","display_login":"vrcorp","gravatar_id":"","url":"https://api.github.com/users/vrcorp","avatar_url":"https://avatars.githubusercontent.com/u/68215251?"},"repo":{"id":1117703620,"name":"vrcorp/captcha-list-vr","url":"https://api.github.com/repos/vrcorp/captcha-list-vr"},"payload":{"repository_id":1117703620,"push_id":29465851800,"ref":"refs/heads/main","head":"d84df4f74d1f53d1ad725c65c8928af08e5e78ba","before":"8cd63080122049ca60c8d15aab90ed611896d5b0"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020188","type":"PushEvent","actor":{"id":187185894,"login":"tylers2222","display_login":"tylers2222","gravatar_id":"","url":"https://api.github.com/users/tylers2222","avatar_url":"https://avatars.githubusercontent.com/u/187185894?"},"repo":{"id":1114132487,"name":"tylers2222/Product-Creation-Agent","url":"https://api.github.com/repos/tylers2222/Product-Creation-Agent"},"payload":{"repository_id":1114132487,"push_id":29465851862,"ref":"refs/heads/main","head":"050da90961e93bee5659066d5886d59cec4cf89e","before":"ce72db60aaf72445df7b31d10502f3ae84b118e8"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020183","type":"PushEvent","actor":{"id":201428757,"login":"JShaurel","display_login":"JShaurel","gravatar_id":"","url":"https://api.github.com/users/JShaurel","avatar_url":"https://avatars.githubusercontent.com/u/201428757?"},"repo":{"id":976674514,"name":"JShaurel/the-dragon-news","url":"https://api.github.com/repos/JShaurel/the-dragon-news"},"payload":{"repository_id":976674514,"push_id":29465851853,"ref":"refs/heads/main","head":"7495425a4cec3307464bf1ec58499a00913d77aa","before":"36c28f6f25902695d7d8e88286ed071760d05a1d"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020182","type":"PushEvent","actor":{"id":244841556,"login":"escapingwork","display_login":"escapingwork","gravatar_id":"","url":"https://api.github.com/users/escapingwork","avatar_url":"https://avatars.githubusercontent.com/u/244841556?"},"repo":{"id":1099385184,"name":"escapingwork/teenagerspopulation","url":"https://api.github.com/repos/escapingwork/teenagerspopulation"},"payload":{"repository_id":1099385184,"push_id":29465851857,"ref":"refs/heads/main","head":"1945c365b27b613e263f2c2f28356b6304198758","before":"dce2348bf59d09e2856e46aa01e5e9cde984947c"},"public":true,"created_at":"2026-01-04T08:18:17Z"},{"id":"7171020181","type":"PushEvent","actor":{"id":241543984,"login":"fahadeleidy-design","display_login":"fahadeleidy-design","gravatar_id":"","url":"https://api.github.com/users/fahadeleidy-design","avatar_url":"https://avatars.githubusercontent.com/u/241543984?"},"repo":{"id":1097444731, ...

# %%
# To create an image from binary data returned by a request, you can use the following code:
from PIL import Image
from io import BytesIO

i = Image.open(BytesIO(r.content))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[5], line 5
#       2 from PIL import Image
#       3 from io import BytesIO
# ----> 5 i = Image.open(BytesIO(r.content))
#
# File /opt/anaconda3/lib/python3.13/site-packages/PIL/Image.py:3580, in open(fp, mode, formats)
#    3578     warnings.warn(message)
#    3579 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3580 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x1452ece00>
