# %% [markdown]
# # Python Resources
#
# A curated collection of high-quality materials to help you learn and master Python — from university courses to reference guides and development tools.
#
# ---
#
# ## 🏫 0. Courses
#
# > Explore foundational and advanced Python programming courses offered by top universities.
#
# - **CS 61A — Structure and Interpretation of Computer Programs**, University of California, Berkeley
#
# - **CS106A — Programming Methodologies**, Stanford University
#
# - **CS50’s Introduction to Programming with Python**, Harvard University
#
# - **CS50’s Introduction to Artificial Intelligence with Python**, Harvard University
#
# - **CS 21 — Introduction to Computer Science**, Swarthmore College
#
#     - _Fall 2023 offering_
#
#
# ---
#
# ## 📘 2. Reference
#
# > Authoritative and high-quality Python documentation, tutorials, and academic resources.
#
# |Title|Link|
# |:--|:--|
# |**The Python Tutorial (v3.11)**|[https://docs.python.org/3.11/tutorial/](https://docs.python.org/3.11/tutorial/)|
# |**Real Python Tutorials**|[https://realpython.com/](https://realpython.com/)|
# |**Learn Python in Y Minutes**|[https://learnxinyminutes.com/docs/python/](https://learnxinyminutes.com/docs/python/)|
# |**CS61A Resources**|[https://cs61a.org/resources/](https://cs61a.org/resources/)|
# |**STA663 (2019) — Advanced Python for Scientific Computing**|[https://people.duke.edu/~ccc14/sta-663-2019/](https://people.duke.edu/~ccc14/sta-663-2019/)|
# |**BIOS821 — Data Science Tools (Duke University)**|[https://people.duke.edu/~ccc14/bios-821-2017/](https://people.duke.edu/~ccc14/bios-821-2017/)|
# |**Python Guide (CS106A @ Stanford)**|[https://cs.stanford.edu/people/nick/py/](https://cs.stanford.edu/people/nick/py/)|
# |**Python Reference (CS21 @ Swarthmore)**|[https://www.cs.swarthmore.edu/pyref/](https://www.cs.swarthmore.edu/pyref/)|
# |**YSP — Advanced Computer Science with Python Lecture Notes**|[https://ww2.cs.fsu.edu/~nienaber/teaching/python/lectures/](https://ww2.cs.fsu.edu/~nienaber/teaching/python/lectures/)|
#
# ---
#
# ## 📖 3. Readings & Notes
#
# ### How-To
#
# - [如何学 Python？ @ 卡瓦邦噶！](https://www.kawabangga.com/posts/4959){:target="_blank"}
#
#
# ### Tutorials
#
# - [Python @ CS50](https://cs50.harvard.edu/python/){:target="_blank"}
#
# - [Python @ cs.lmu.edu/~ray](https://cs.lmu.edu/~ray/notes/python/){:target="_blank"}
#
#
# ### Coding Style
#
# - **CS 4410/11 Coding Style Guide**
#
#
# ### Others
#
# - [PyFormat](https://pyformat.info/){:target="_blank"} — A guide to Python string formatting
#
#
# ---
#
# ## ⚙️ 4. Tools & Guides
#
# > IDEs, online environments, and other helpful utilities for learning and experimenting with Python.
#
# ### 🧩 Online Tools
#
# - **[Python Tutor](https://pythontutor.com/python-debugger.html#mode=edit){:target="_blank"}** — Visualize code execution in Python, JavaScript, C, C++, and Java
#
#     - Python version: [Main site](https://pythontutor.com/python-debugger.html#mode=edit)
#
#     - From CS61A: [Composing Programs Visualizer](https://pythontutor.com/cp/composingprograms.html#mode=edit)
#
# - **CS61A Code Environment**
#
# - **[OnlineGDB for Python](https://www.onlinegdb.com/online_python_compiler){:target="_blank"}**
#
#
# ---
#
# - **Learn Python 3** — [learnpython.org](https://www.learnpython.org/){:target="_blank"}
# - https://www.python123.io/
